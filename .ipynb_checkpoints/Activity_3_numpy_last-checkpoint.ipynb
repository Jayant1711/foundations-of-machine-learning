# %%
import numpy as np
# electricity=np.array((4,7))
# rows hostels 1 to 4
# clolunms monday to sunday
# task a1
electricity=np.random.randint(120,650,28)
electricity=electricity.reshape(4,7)
print(electricity)

# task a2
print(electricity.shape,electricity.ndim,electricity.size,electricity.dtype)
# Out:
# [[164 358 343 235 428 123 162]
#  [646 420 417 158 537 122 623]
#  [286 144 261 391 609 643 563]
#  [629 604 549 448 312 233 289]]
# (4, 7) 2 28 int32

# %%
# task b2
print(electricity.mean(axis=1).reshape(4,1))
# hostel 4 has highest usage

# task b2

print(electricity.sum(axis=0))

# friday is day of max consumption
# Out:
# [[259.        ]
#  [417.57142857]
#  [413.85714286]
#  [437.71428571]]
# [1725 1526 1570 1232 1886 1121 1637]

# %%
# task c1

new_electricity=np.where(electricity>550,electricity*1.20,electricity)
print(new_electricity)
# Out:
# [[164.  358.  343.  235.  428.  123.  162. ]
#  [775.2 420.  417.  158.  537.  122.  747.6]
#  [286.  144.  261.  391.  730.8 771.6 675.6]
#  [754.8 724.8 549.  448.  312.  233.  289. ]]

# %%
# task c4
ab=electricity.mean(axis=1).reshape(4,1)
print(np.where(electricity>ab,True,False))
# Out:
# [[False  True  True False  True False False]
#  [ True  True False False  True False  True]
#  [False False False False  True  True  True]
#  [ True  True  True  True False False False]]

# %%
# task e1
print(electricity.reshape(1,28))
# Out:
# [[164 358 343 235 428 123 162 646 420 417 158 537 122 623 286 144 261 391
#   609 643 563 629 604 549 448 312 233 289]]

# %%
# task e2
print(electricity.reshape(2,14))
# Out:
# [[164 358 343 235 428 123 162 646 420 417 158 537 122 623]
#  [286 144 261 391 609 643 563 629 604 549 448 312 233 289]]

# %%
# task f1

backup=electricity
good_backup=electricity.copy()
electricity[0:1,0:1]=1
print(backup)
# changed in back up too
# Out:
# [[  1 358 343 235 428 123 162]
#  [646 420 417 158 537 122 623]
#  [286 144 261 391 609 643 563]
#  [629 604 549 448 312 233 289]]
